# %% [markdown]
# <a href="https://colab.research.google.com/github/pk2971/Web-scraper/blob/main/WebScrapingNandhini(2000surls)_Praharshita_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
def getdata(url): 
    r = requests.get(url) 
    return r.text

def extractData(url):
  htmldata = getdata(url) 
  soup = BeautifulSoup(htmldata) 
  data = '' 
  for data in soup.find_all('p'): 
  #for data in soup.select('p'):
    print(data.get_text())

# %%
# extracting the data from one webpage
extractData('https://api.parliament.uk/historic-hansard/commons/1943/may/11/war-time-missions-united-states')
# Out:
#             asked the Financial Secretary to the Treasury the total numbers of the personnel of the United Kingdom war-time Missions in the United States of America, Service as well as civilian; and the proportion of this total represented by locally recruited staff?
#
#
#             The total number of staff in the United Kingdom war-time Missions in the United States at the end of February, the latest date for which figures are available, was aproximately 8,750. More than four-fifths of this total was represented by locally recruited staff, and of the United Kingdom based staff a substantial
#             478
#             part were, of course, Service, not civilian, personnel.
#
#
#             Will my hon. Friend give as much publicity as possible to his answer in order to do away with the impression current in this country that there are 8,000 people from this country in Washington?
#
#
#             I fully appreciate the point.
#
#
#             Can my hon. Friend say whether there has been any substantial reduction in those employed since his right hon. and gallant Friend left the Treasury to become Postmaster-General?
#
#
#             I should like to have notice of that question.
#
# Noticed a typo? | Report other issues | &copy UK Parliament

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
r = requests.get("https://api.parliament.uk/historic-hansard/commons/1943/may/11/war-time-missions-united-states")

# Convert to a beautiful soup object

soup = bs(r.content)

# Print out HTML
# The prettify() method will turn a Beautiful Soup parse tree  
# into a nicely formatted Unicode string, with a separate line for each tag and each string
contents = soup.prettify()
print(contents)
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    WAR-TIME MISSIONS, UNITED STATES (Hansard, 11 May 1943)
#   </title>
#   <meta author="UK Parliament"/>
#   <meta content="51ff727eff55314a" name="y_key"/>
#   <link href="https://www.parliament.uk/site-information/copyright/" rel="copyright"/>
#   <meta content="Hansard, House of Commons, House of Lords, Parliament, UK, House of Commons sitting" name="keywords"/>
#   <meta content="WAR-TIME MISSIONS, UNITED STATES (Hansard, 11 May 1943)" name="description"/>
#   <link href="../../../../stylesheets/screen.css" media="screen" rel="stylesheet" title="Default" type="text/css"/>
#   <link href="../../../../stylesheets/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    var appInsights=window.appInsights||function(a){
#     function b(a){c[a]=function(){var b=arguments;c.queue.push(function(){c[a].apply(c,b)})}}var c={config:a},d=document,e=window;setTimeout(function(){var b=d.createElement("script");b.src=a.url||"https://az416426.vo.msecnd.net/scripts/a/ai.0.js",d.getElementsByTagName("script")[0].parentNode.appendChild(b)});try{c.cookie=d.cookie}catch(a){}c.queue=[];for(var f=["Event","Exception","Metric","PageView","Trace","Dependency"];f.length;)b("track"+f.pop());if(b("setAuthenticatedUserContext"),b("clearAuthenticatedUserContext"),b("startTrackEvent"),b("stopTrackEvent"),b("startTrackPage"),b("stopTrackPage"),b("flush"),!a.disableExceptionTracking){f="onerror",b("_"+f);var g=e[f];e[f]=function(a,b,d,e,h){var i=g&&g(a,b,d,e,h);return!0!==i&&c["_"+f](a,b,d,e,h),i}}return c
#     }({
#         instrumentationKey:"c0960a0f-30ad-4a9a-b508-14c6a4f61179",
#         cookieDomain:".parliament.uk"
#     });
#
#   window.appInsights=appInsights,appInsights.queue&&0===appInsights.queue.length&&appInsights.trackPageView();
#   </script>
#  </head>
#  <body id="hansard-millbanksytems-com">
#   <div id="header">
#    <div class="search-help">
#     <a href="../../../../search">
#      Search Help
#     </a>
#    </div>
#    <form action="../../../../search" id="search" method="get" rel="search">
#     <input accesskey="s" autosave="hansard.millbanksystems.com" id="search-query" name="query" placeholder="Search Hansard" results="10" size="24" title="Access key: S" type="search" value=""/>
#     <input type="submit" value="Search"/>
#    </form>
#    <div id="nav">
#     <a href="../../../../index.html" id="home" rel="home">
#      HANSARD 1803–2005
#     </a>
#     →
#     <a class="sitting-decade" href="../../../../sittings/1940s">
#      1940s
#     </a>
#     →
#     <a class="sitting-year" href="../../../../sittings/1943/">
#      1943
#     </a>
#     →
#     <a class="sitting-month" href="../../../../sittings/1943/may/">
#      May 1943
#     </a>
#     →
#     <a class="sitting-day" href="../../../../sittings/1943/may/11">
#      11 May 1943
#     </a>
#     →
#     <a href="../../../../sittings/1943/may/11#commons" rel="directory up">
#      Commons Sitting
#     </a>
#     →
#     <a href="national-finance">
#      NATIONAL FINANCE
#     </a>
#    </div>
#    <h1 class="title">
#     WAR-TIME MISSIONS, UNITED STATES
#    </h1>
#   </div>
#   <div class="house-of-commons-sitting" id="content">
#    <cite class="section">
#     HC Deb 11 May 1943 vol 389 cc477-8
#    </cite>
#    <a class="permalink column-permalink" href="war-time-missions-united-states#column_477" id="column_477" name="column_477" rel="bookmark" title="Col. 477 — HC Deb 11 May 1943 vol 389 c477">
#     477
#    </a>
#    <div class="hentry member_contribution" id="S5CV0389P0-02301">
#     <a name="S5CV0389P0_19430511_HOC_180">
#     </a>
#     <blockquote cite="https://api.parliament.uk/historic-hansard/people/mr-john-wardlaw-milne" class="contribution_text entry-content">
#      <a class="speech-permalink permalink" href="war-time-missions-united-states#S5CV0389P0_19430511_HOC_180" rel="bookmark" title="Link to this speech by Mr John Wardlaw-Milne">
#       §
#      </a>
#      <span class="question_no">
#       44.
#      </span>
#      <cite class="member author entry-title">
#       <a href="/historic-hansard/people/mr-john-wardlaw-milne" title="Mr John Wardlaw-Milne">
#        Sir John Wardlaw-Milne
#       </a>
#      </cite>
#      <p class="first-para">
#       asked the Financial Secretary to the Treasury the total numbers of the personnel of the United Kingdom war-time Missions in the United States of America, Service as well as civilian; and the proportion of this total represented by locally recruited staff?
#      </p>
#     </blockquote>
#    </div>
#    <div class="hentry member_contribution" id="S5CV0389P0-02302">
#     <a name="S5CV0389P0_19430511_HOC_181">
#     </a>
#     <blockquote cite="https://api.parliament.uk/historic-hansard/people/mr-ralph-assheton-1" class="contribution_text entry-content">
#      <a class="speech-permalink permalink" href="war-time-missions-united-states#S5CV0389P0_19430511_HOC_181" rel="bookmark" title="Link to this speech by Mr Ralph Assheton">
#       §
#      </a>
#      <cite class="member author entry-title">
#       <a href="/historic-hansard/people/mr-ralph-assheton-1" title="Mr Ralph Assheton">
#        Mr. Assheton
#       </a>
#      </cite>
#      <p class="first-para">
#       The total number of staff in the United Kingdom war-time Missions in the United States at the end of February, the latest date for which figures are available, was aproximately 8,750. More than four-fifths of this total was represented by locally recruited staff, and of the United Kingdom based staff a substantial
#       <a class="permalink column-permalink" href="war-time-missions-united-states#column_478" id="column_478" name="column_478" rel="bookmark" title="Col. 478 — HC Deb 11 May 1943 vol 389 c478">
#        478
#       </a>
#       part were, of course, Service, not civilian, personnel.
#      </p>
#     </blockquote>
#    </div>
#    <div class="hentry member_contribution" id="S5CV0389P0-02303">
#     <a name="S5CV0389P0_19430511_HOC_182">
#     </a>
#     <blockquote cite="https://api.parliament.uk/historic-hansard/people/mr-john-wardlaw-milne" class="contribution_text entry-content">
#      <a class="speech-permalink permalink" href="war-time-missions-united-states#S5CV0389P0_19430511_HOC_182" rel="bookmark" title="Link to this speech by Mr John Wardlaw-Milne">
#       §
#      </a>
#      <cite class="member author entry-title">
#       <a href="/historic-hansard/people/mr-john-wardlaw-milne" title="Mr John Wardlaw-Milne">
#        Sir J. Wardlaw-Milne
#       </a>
#      </cite>
#      <p class="first-para">
#       Will my hon. Friend give as much publicity as possible to his answer in order to do away with the impression current in this country that there are 8,000 people from this country in Washington?
#      </p>
#     </blockquote>
#    </div>
#    <div class="hentry member_contribution" id="S5CV0389P0-02304">
#     <a name="S5CV0389P0_19430511_HOC_183">
#     </a>
#     <blockquote cite="https://api.parliament.uk/historic-hansard/people/mr-ralph-assheton-1" class="contribution_text entry-content">
#      <a class="speech-permalink permalink" href="war-time-missions-united-states#S5CV0389P0_19430511_HOC_183" rel="bookmark" title="Link to this speech by Mr Ralph Assheton">
#       §
#      </a>
#      <cite class="member author entry-title">
#       <a href="/historic-hansard/people/mr-ralph-assheton-1" title="Mr Ralph Assheton">
#        Mr. Assheton
#       </a>
#      </cite>
#      <p class="first-para">
#       I fully appreciate the point.
#      </p>
#     </blockquote>
#    </div>
#    <div class="hentry member_contribution" id="S5CV0389P0-02305">
#     <a name="S5CV0389P0_19430511_HOC_184">
#     </a>
#     <blockquote cite="https://api.parliament.uk/historic-hansard/people/mr-irving-albery" class="contribution_text entry-content">
#      <a class="speech-permalink permalink" href="war-time-missions-united-states#S5CV0389P0_19430511_HOC_184" rel="bookmark" title="Link to this speech by Mr Irving Albery">
#       §
#      </a>
#      <cite class="member author entry-title">
#       <a href="/historic-hansard/people/mr-irving-albery" title="Mr Irving Albery">
#        Sir Irvinǵ Albery
#       </a>
#      </cite>
#      <p class="first-para">
#       Can my hon. Friend say whether there has been any substantial reduction in those employed since his right hon. and gallant Friend left the Treasury to become Postmaster-General?
#      </p>
#     </blockquote>
#    </div>
#    <div class="hentry member_contribution" id="S5CV0389P0-02306">
#     <a name="S5CV0389P0_19430511_HOC_185">
#     </a>
#     <blockquote cite="https://api.parliament.uk/historic-hansard/people/mr-ralph-assheton-1" class="contribution_text entry-content">
#      <a class="speech-permalink permalink" href="war-time-missions-united-states#S5CV0389P0_19430511_HOC_185" rel="bookmark" title="Link to this speech by Mr Ralph Assheton">
#       §
#      </a>
#      <cite class="member author entry-title">
#       <a href="/historic-hansard/people/mr-ralph-assheton-1" title="Mr Ralph Assheton">
#        Mr. Assheton
#       </a>
#      </cite>
#      <p class="first-para">
#       I should like to have notice of that question.
#      </p>
#     </blockquote>
#    </div>
#    <ol class="xoxo">
#    </ol>
#    <div id="section-navigation">
#     <div id="previous-section">
#      Back to
#      <a href="statutory-rules-and-orders" rel="prev">
#       STATUTORY RULES AND ORDERS
#      </a>
#     </div>
#     <div id="next-section">
#      Forward to
#      <a href="rudolf-hess" rel="next">
#       RUDOLF HESS
#      </a>
#     </div>
#    </div>
#   </div>
#   <div id="footer">
#    <p>
#     <a href="../../../../typos">
#      Noticed a typo?
#     </a>
#     |
#     <a href="mailto:data@parliament.uk" target="_BLANK" title="Opens a new page">
#      Report other issues
#     </a>
#     |
#     <a href="https://www.parliament.uk/site-information/copyright/" id="copyright" rel="copyright">
#      &amp;copy UK Parliament
#     </a>
#    </p>
#    <script type="text/javascript">
#     var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
#         document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
#    </script>
#    <script type="text/javascript">
#     var pageTracker = _gat._getTracker("UA-3110135-1");
#         pageTracker._initData();
#    </script>
#   </div>
#  </body>
# </html>

# %%
def extractDatadict(url):
  htmldata = getdata(url) 
  soup = BeautifulSoup(htmldata) 
  data = '' 
  for data in soup.find_all('p'): 
  #for data in soup.select('p'):
    return data.get_text()

# %% [markdown]
# Save this information in the form of a dictionary:
# Date, title and conversation text.

# %%
import pandas as pd 
links_url = pd.read_csv('links2000s.csv')
links_url.head()
# Out:
# Empty DataFrame
# Columns: [/historic-hansard/commons/2000/jan/10/preamble, /historic-hansard/commons/2000/jan/10/prayers, /historic-hansard/commons/2000/jan/10/oral-answers-to-questions, /historic-hansard/commons/2000/jan/10/social-security, /historic-hansard/commons/2000/jan/10/severe-disablement-allowance, /historic-hansard/commons/2000/jan/10/child-poverty, /historic-hansard/commons/2000/jan/10/carers, /historic-hansard/commons/2000/jan/10/advance-corporation-tax, /historic-hansard/commons/2000/jan/10/disability-benefits, /historic-hansard/commons/2000/jan/10/all-work-test, /historic-hansard/commons/2000/jan/10/child-support-agency, /historic-hansard/commons/2000/jan/10/winter-fuel-payments, /historic-hansard/commons/2000/jan/10/information-technology, /historic-hansard/commons/2000/jan/10/local-exchange-trading-schemes, /historic-hansard/commons/2000/jan/10/women-pensioners, /historic-hansard/commons/2000/jan/10/voluntary-sector, /historic-hansard/commons/2000/jan/10/child-support-agency-1, /historic-hansard/commons/2000/jan/10/benefit-reform, /historic-
# ['/historic-hansard/commons/2000/jan/10/preamble', '/historic-hansard/commons/2000/jan/10/prayers', '/historic-hansard/commons/2000/jan/10/oral-answers-to-questions']

# %%
links_small = links_url_list[4000:12000]

# %%
links_url_list[3999]
# Out:
# '/historic-hansard/commons/2000/jun/19/prayers'

# %%
len(links_small)
# Out:
# 8000

# %%
import time
import random
def get_data(link):
 return requests.get(link)
 
def get_soup(data):
   soup = bs(data.content)
   return soup
 
def get_parser(data):
   text = data.text
   htmlParse = BeautifulSoup(text, "html.parser")
   return htmlParse

def construct_data_list(links):
  # looping through the links
  link_list = links

  # creating a new list            
  hansard_info_list = []
  n=0

  # for every link in the list of links
  for link in link_list:


    # appending the string to the link
    # to get the entire link
    if(n<10):
      print("Extracting ",link)
      #print(n)
      string = "https://api.parliament.uk"
      link = string + link

    # creating a dictionary entry called hansard_info
      hansard_info = {}
      data = get_data(link)
      soup = get_soup(data)

    # getting the date for each link
      hansard_info['date'] = soup.find(class_="sitting-day").get_text(" ", strip = True)
      parser = get_parser(data)
    # extracting the title for each link
      hansard_info['title'] = parser.select('h1.title')[0].text.strip()
    # extracting the conversation from the webpage for each link
      hansard_info['conversation'] = [p.get_text(strip=True, separator='\n') for p in soup.find_all("p")]
    # getting rid of "noticed a typo?"
      hansard_info['conversation'] = hansard_info['conversation'][:-1]
    # appending this dictionary entry the list of ditionary entries
      hansard_info_list.append(hansard_info)
      n+=1
    else:
      x=random.randrange(1,6)
      print("Sleeping for ",x," seconds")
      time.sleep(x)
      n=0
  return hansard_info_list

# %%
#dont run this will print everything
construct_data_list(links_small)

# %% [markdown]
# Convert list of dictionary entries into a csv file

# %%
#run from here
import pandas as pd

# %%
# converting a list of dictionary elements into a csv file
import csv

to_csv = construct_data_list(links_small)

keys = to_csv[0].keys()

with open('hansard.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(to_csv)
# Out:
# Extracting  /historic-hansard/commons/2000/jun/19/oral-answers-to-questions
# Extracting  /historic-hansard/commons/2000/jun/19/social-security
# Extracting  /historic-hansard/commons/2000/jun/19/pensioners
# Extracting  /historic-hansard/commons/2000/jun/19/single-parents
# Extracting  /historic-hansard/commons/2000/jun/19/pensioners-1
# Extracting  /historic-hansard/commons/2000/jun/19/appeal-procedure
# Extracting  /historic-hansard/commons/2000/jun/19/child-care
# Extracting  /historic-hansard/commons/2000/jun/19/early-retirement
# Extracting  /historic-hansard/commons/2000/jun/19/new-deal-disabled-people
# Extracting  /historic-hansard/commons/2000/jun/19/pensioners-2
# Sleeping for  4  seconds
# Extracting  /historic-hansard/commons/2000/jun/19/dividend-tax-credits
# Extracting  /historic-hansard/commons/2000/jun/19/lone-parents
# Extracting  /historic-hansard/commons/2000/jun/19/national-air-traffic-services
# Extracting  /historic-hansard/commons/2000/jun/19/deaths-at-dover
# Extracting  /historic-hansard/commons/2000/jun/19/euro-2000
# Extracting  /historic-hansard/commons/2000/jun/19/house-of-lords-reform
# Extracting  /historic-hansard/commons/2000/jun/27/amendments-relating-to-external
# Extracting  /historic-hansard/commons/2000/jun/27/clause-100
# Sleeping for  4  seconds
# Extracting  /historic-hansard/commons/2000/jun/27/clause-101
# Extracting  /historic-hansard/commons/2000/jun/27/qualifying-arrangements
# Extracting  /historic-hansard/commons/2000/jun/27/clause-102
# Extracting  /historic-hansard/commons/2000/jun/27/qualifying-arrangements-further-provision
# Extracting  /historic-hansard/commons/2000/jun/27/clause-108
# Extracting  /historic-hansard/commons/2000/jun/27/provision-of-services
# Extracting  /historic-hansard/commons/2000/jun/27/clause-111
# Extracting  /historic-hansard/commons/2000/jun/27/educational-institutionsinformation-and
# Extracting  /historic-hansard/commons/2000/jun/27/clause-114
# Extracting  /historic-hansard/commons/2000/jun/27/information-supply-by-public-bodies
# Sleeping for  3  seconds
# Extracting  /historic-hansard/commons/2000/jun/27/inadequate-sixth-forms
# Extracting  /historic-hansard/commons/2000/jun/27/delegated-legislation
# Extracting  /historic-hansard/commons/2000/jun/27/criminal-law
# Extracting  /historic-hansard/commons/2000/jun/27/estimates
# Extracting  /historic-hansard/commons/2000/jun/27/petition
# Extracting  /historic-hansard/commons/2000/jun/27/religious-broadcasting
# Extracting  /historic-hansard/commons/2000/jun/27/planning-policy-chelmsford
# Extracting  /historic-hansard/commons/2000/jun/28/preamble
# Extracting  /historic-hansard/commons/2000/jun/28/prayers
# Extracting  /historic-hansard/commons/2000/jun/28/private-business
# Sleeping for  5  seconds
# Extracting  /historic-hansard/commons/2000/jun/28/oral-answers-to-questions
# Extracting  /historic-hansard/commons/2000/jun/28/wales
# Extracting  /historic-hansard/commons/2000/jun/28/health-service
# Extracting  /historic-hansard/commons/2000/jun/28/transport
# Extracting  /historic-hansard/commons/2000/jun/28/nhs-waiting-lists
# Extracting  /historic-hansard/commons/2000/jun/28/hunting
# Extracting  /historic-hansard/commons/2000/jun/28/national-parks
# Extracting  /historic-hansard/commons/2000/jun/28/unemployment
# Extracting  /historic-hansard/commons/2000/jun/28/aerospace-industry
# Extracting  /historic-hansard/commons/2000/jun/28/economy-deeside
# Sleeping for  1  seconds
# Extracting  /historic-hansard/commons/2000/jun/28/prime-minister
# Extracting  /historic-hansard/commons/2000/jun/28/engagements
# Extracting  /historic-hansard/commons/2000/jun/28/ministerial-visits
# Extracting  /historic-hansard/commons/2000/jun/28/engagements-1
# Extracting  /historic-hansard/commons/2000/jun/28/post-office-network
# Extracting  /historic-hansard/commons/2000/jun/28/points-of-order
# Extracting  /historic-hansard/commons/2000/jun/28/house-of-commons-reserved-matters
# Extracting  /historic-hansard/commons/2000/jun/28/orders-of-the-day
# Extracting  /historic-hansard/commons/2000/jun/28/limited-liability-partnerships-bill
# Extracting  /historic-hansard/commons/2000/jun/28/new-clause-2
# Sleeping for  5  seconds
# Extracting  /historic-hansard/commons/2000/jun/28/clause-5
# Extracting  /historic-hansard/commons/2000/jun/28/relationship-of-members-etc
# Extracting  /historic-hansard/commons/2000/jun/28/clause-15
# Extracting  /historic-hansard/commons/2000/jun/28/application-oe-company-law-etc
# Extracting  /historic-hansard/commons/2000/jun/28/schedule
# Extracting  /historic-hansard/commons/2000/jun/28/names-and-registered-offices
# Extracting  /historic-hansard/commons/2000/jun/28/fur-farming-prohibition-bill
# Extracting  /historic-hansard/commons/2000/jun/28/clause-2
# Extracting  /historic-hansard/commons/2000/jun/28/forfeiture-orders
# Extracting  /historic-hansard/commons/2000/jun/28/clause-5-1
# Sleeping for  1  seconds
# Extracting  /historic-hansard/commons/2000/jun/28/delegated-legislation
# Extracting  /historic-hansard/commons/2000/jun/28/parliament
# Extracting  /historic-hansard/commons/2000/jun/28/agricultural-wages-boards
# Extracting  /historic-hansard/commons/2000/jun/29/preamble
# Extracting  /historic-hansard/commons/2000/jun/29/prayers
# Extracting  /historic-hansard/commons/2000/jun/29/private-business
# Extracting  /historic-hansard/commons/2000/jun/29/oral-answers-to-questions
# Extracting  /historic-hansard/commons/2000/jun/29/agriculture-fisheries-and-food
# Extracting  /historic-hansard/commons/2000/jun/29/common-agricultural-policy
# Extracting  /historic-hansard/commons/2000/jun/29/gm-crops
# Sleeping for  2  seconds
# Extracting  /historic-hansard/commons/2000/jun/29/exchange-rates
# Extracting  /historic-hansard/commons/2000/jun/29/organic-farming
# Extracting  /historic-hansard/commons/2000/jun/29/milk-prices
# Extracting  /historic-hansard/commons/2000/jun/29/wheat-prices
# Extracting  /historic-hansard/commons/2000/jun/29/iacs-payments
# Extracting  /historic-hansard/commons/2000/jun/29/hill-farmers
# Extracting  /historic-hansard/commons/2000/jun/29/arable-stewardship-scheme
# Extracting  /historic-hansard/commons/2000/jun/29/solicitor-general
# Extracting  /historic-hansard/commons/2000/jun/29/judicial-conference
# Extracting  /historic-hansard/commons/2000/jun/29/legal-costs
# Sleeping for  5  seconds
# Extracting  /historic-hansard/commons/2000/jun/29/fraud
# Extracting  /historic-hansard/commons/2000/jun/29/agriculture-fisheries-and-food-1
# Extracting  /historic-hansard/commons/2000/jun/29/bse
# Extracting  /historic-hansard/commons/2000/jun/29/business-of-the-house
# Extracting  /historic-hansard/commons/2000/jun/29/opposition-day-15th-allotted-day
# Extracting  /historic-hansard/commons/2000/jun/29/national-health-service
# Extracting  /historic-hansard/commons/2000/jun/29/adjournment
# Extracting  /historic-hansard/commons/2000/jul/03/preamble
# Extracting  /historic-hansard/commons/2000/jul/03/prayers
# Extracting  /historic-hansard/commons/2000/jul/03/oral-answers-to-questions
# Sleeping for  2  seconds
# Extracting  /historic-hansard/commons/2000/jul/03/missile-defence-system
# Extracting  /historic-hansard/commons/2000/jul/03/european-defence
# Extracting  /historic-hansard/commons/2000/jul/03/sierra-leone
# Extracting  /historic-hansard/commons/2000/jul/03/surplus-assets
# Extracting  /historic-hansard/commons/2000/jul/03/army-exercises
# Extracting  /historic-hansard/commons/2000/jul/03/troop-deployments
# Extracting  /historic-hansard/commons/2000/jul/03/aircraft-weaponry
# Extracting  /historic-hansard/commons/2000/jul/03/naval-funding
# Extracting  /historic-hansard/commons/2000/jul/03/former-prisoners-of-war
# Extracting  /historic-hansard/commons/2000/jul/03/defence-medical-services
# Sleeping for  1  seconds
# Extracting  /historic-hansard/commons/2000/jul/03/naval-procurement
# Extracting  /historic-hansard/commons/2000/jul/03/point-of-order
# Extracting  /historic-hansard/commons/2000/jul/03/opposition-day
# Extracting  /historic-hansard/commons/2000/jul/03/prisoners-early-release
# Extracting  /historic-hansard/commons/2000/jul/03/neill-committee-ministers-and-special
# Extracting  /historic-hansard/commons/2000/jul/03/delegated-legislation
# Extracting  /historic-hansard/commons/2000/jul/03/northern-ireland
# Extracting  /historic-hansard/commons/2000/jul/03/stakeholder-pension-scheme-regulations
# Extracting  /historic-hansard/commons/2000/jul/03/airport-regulation
# Extracting  /historic-hansard/commons/2000/jul/04/preamble
# Sleeping for  2  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/private-business
# Extracting  /historic-hansard/commons/2000/jul/04/alliance-and-leicester-group-treasury
# Extracting  /historic-hansard/commons/2000/jul/04/city-of-newcastle-upon-tyne-bill-lords
# Extracting  /historic-hansard/commons/2000/jul/04/greenham-and-crookham-commons-bill-by
# Extracting  /historic-hansard/commons/2000/jul/04/oral-answers-to-questions
# Extracting  /historic-hansard/commons/2000/jul/04/health
# Extracting  /historic-hansard/commons/2000/jul/04/childrens-hospices
# Extracting  /historic-hansard/commons/2000/jul/04/commission-for-health-improvement
# Extracting  /historic-hansard/commons/2000/jul/04/nice-drugs
# Extracting  /historic-hansard/commons/2000/jul/04/nhs-trusts-mergers
# Sleeping for  5  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/air-ambulance-services
# Extracting  /historic-hansard/commons/2000/jul/04/infant-deaths
# Extracting  /historic-hansard/commons/2000/jul/04/mental-health
# Extracting  /historic-hansard/commons/2000/jul/04/cataract-operations
# Extracting  /historic-hansard/commons/2000/jul/04/prostate-cancer
# Extracting  /historic-hansard/commons/2000/jul/04/whittington-hospital
# Extracting  /historic-hansard/commons/2000/jul/04/hygiene-nhs-hospitals
# Extracting  /historic-hansard/commons/2000/jul/04/nice
# Extracting  /historic-hansard/commons/2000/jul/04/civil-list
# Extracting  /historic-hansard/commons/2000/jul/04/football-hooliganism
# Sleeping for  4  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/planning-provision-of-affordable-housing
# Extracting  /historic-hansard/commons/2000/jul/04/planning-provision-of-affordable-housing-1
# Extracting  /historic-hansard/commons/2000/jul/04/orders-of-the-day
# Extracting  /historic-hansard/commons/2000/jul/04/local-government-bill-lords-programme
# Extracting  /historic-hansard/commons/2000/jul/04/report-and-third-reading
# Extracting  /historic-hansard/commons/2000/jul/04/proceedings-on-consideration
# Extracting  /historic-hansard/commons/2000/jul/04/conclusion-of-proceedings
# Extracting  /historic-hansard/commons/2000/jul/04/miscellaneous
# Extracting  /historic-hansard/commons/2000/jul/04/supplementary-provisions
# Extracting  /historic-hansard/commons/2000/jul/04/report-and-third-reading-1
# Sleeping for  3  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/conclusion-of-proceedings-1
# Extracting  /historic-hansard/commons/2000/jul/04/miscellaneous-1
# Extracting  /historic-hansard/commons/2000/jul/04/supplementary-provisions-1
# Extracting  /historic-hansard/commons/2000/jul/04/local-government-bill-lords
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-8
# Extracting  /historic-hansard/commons/2000/jul/04/power-to-modify-enactments-concerning
# Extracting  /historic-hansard/commons/2000/jul/04/clause-2
# Extracting  /historic-hansard/commons/2000/jul/04/promotion-of-well-being
# Extracting  /historic-hansard/commons/2000/jul/04/clause-6
# Extracting  /historic-hansard/commons/2000/jul/04/power-to-modify-enactments-concerning-1
# Sleeping for  5  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/amendments-to-the-1972-act
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-1
# Extracting  /historic-hansard/commons/2000/jul/04/local-authority-to-decide-whether-to
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-7
# Extracting  /historic-hansard/commons/2000/jul/04/application-for-locally-developed
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-10
# Extracting  /historic-hansard/commons/2000/jul/04/prior-discussion-by-political-groups
# Extracting  /historic-hansard/commons/2000/jul/04/new-schedule-1
# Extracting  /historic-hansard/commons/2000/jul/04/amendments-to-the-1972-act-1
# Extracting  /historic-hansard/commons/2000/jul/04/clause-12
# Sleeping for  3  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/clause-14
# Extracting  /historic-hansard/commons/2000/jul/04/discharge-of-functions-leader-and
# Extracting  /historic-hansard/commons/2000/jul/04/clause-15
# Extracting  /historic-hansard/commons/2000/jul/04/discharge-of-functions-mayor-and-council
# Extracting  /historic-hansard/commons/2000/jul/04/clause-17
# Extracting  /historic-hansard/commons/2000/jul/04/discharge-of-functions-by-area-committees
# Extracting  /historic-hansard/commons/2000/jul/04/clause-18
# Extracting  /historic-hansard/commons/2000/jul/04/discharge-of-functions-of-and-by-another
# Extracting  /historic-hansard/commons/2000/jul/04/clause-20
# Extracting  /historic-hansard/commons/2000/jul/04/overview-and-scrutiny-committees
# Sleeping for  1  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/access-to-information-background-papers
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-11
# Extracting  /historic-hansard/commons/2000/jul/04/meetings-and-documents-notice-etc
# Extracting  /historic-hansard/commons/2000/jul/04/clause-21
# Extracting  /historic-hansard/commons/2000/jul/04/access-to-information-etc
# Extracting  /historic-hansard/commons/2000/jul/04/schedule-1
# Extracting  /historic-hansard/commons/2000/jul/04/executive-arrangements-further-provision
# Extracting  /historic-hansard/commons/2000/jul/04/clause-26
# Extracting  /historic-hansard/commons/2000/jul/04/referendum-in-case-of-proposals
# Extracting  /historic-hansard/commons/2000/jul/04/clause-27
# Sleeping for  1  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/clause-30
# Extracting  /historic-hansard/commons/2000/jul/04/alternative-arrangements
# Extracting  /historic-hansard/commons/2000/jul/04/clause-32
# Extracting  /historic-hansard/commons/2000/jul/04/referendum-following-petition
# Extracting  /historic-hansard/commons/2000/jul/04/clause-35
# Extracting  /historic-hansard/commons/2000/jul/04/information-with-respect-to-discharge-of
# Extracting  /historic-hansard/commons/2000/jul/04/clause-37
# Extracting  /historic-hansard/commons/2000/jul/04/elected-mayors-etc
# Extracting  /historic-hansard/commons/2000/jul/04/clause-39
# Extracting  /historic-hansard/commons/2000/jul/04/time-of-elections-etc
# Sleeping for  3  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/power-to-make-provision-about-elections
# Extracting  /historic-hansard/commons/2000/jul/04/clause-45
# Extracting  /historic-hansard/commons/2000/jul/04/interpretation-of-part-ii
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-3
# Extracting  /historic-hansard/commons/2000/jul/04/restitution-order
# Extracting  /historic-hansard/commons/2000/jul/04/clause-46
# Extracting  /historic-hansard/commons/2000/jul/04/principles-governing-conduct-of-members
# Extracting  /historic-hansard/commons/2000/jul/04/clause-47
# Extracting  /historic-hansard/commons/2000/jul/04/model-code-of-conduct
# Extracting  /historic-hansard/commons/2000/jul/04/clause-48
# Sleeping for  5  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/clause-50
# Extracting  /historic-hansard/commons/2000/jul/04/standards-committees
# Extracting  /historic-hansard/commons/2000/jul/04/clause-51
# Extracting  /historic-hansard/commons/2000/jul/04/functions-of-standards-committees
# Extracting  /historic-hansard/commons/2000/jul/04/clause-54
# Extracting  /historic-hansard/commons/2000/jul/04/standards-board-for-england
# Extracting  /historic-hansard/commons/2000/jul/04/clause-61
# Extracting  /historic-hansard/commons/2000/jul/04/reports-etc
# Extracting  /historic-hansard/commons/2000/jul/04/clause-65
# Extracting  /historic-hansard/commons/2000/jul/04/local-commissioner-and-commission-for
# Sleeping for  4  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/investigations-by-local-commissioner-in
# Extracting  /historic-hansard/commons/2000/jul/04/clause-68
# Extracting  /historic-hansard/commons/2000/jul/04/reports-etc-1
# Extracting  /historic-hansard/commons/2000/jul/04/clause-69
# Extracting  /historic-hansard/commons/2000/jul/04/interim-reports
# Extracting  /historic-hansard/commons/2000/jul/04/clause-70
# Extracting  /historic-hansard/commons/2000/jul/04/matters-referred-to-monitoring-officers
# Extracting  /historic-hansard/commons/2000/jul/04/clause-78
# Extracting  /historic-hansard/commons/2000/jul/04/disclosure-and-registration-of-members
# Extracting  /historic-hansard/commons/2000/jul/04/clause-79
# Sleeping for  2  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/clause-80
# Extracting  /historic-hansard/commons/2000/jul/04/interpretation-of-part-iii
# Extracting  /historic-hansard/commons/2000/jul/04/new-clause-4
# Extracting  /historic-hansard/commons/2000/jul/04/proportional-representation-for-local
# Extracting  /historic-hansard/commons/2000/jul/04/clause-88
# Extracting  /historic-hansard/commons/2000/jul/04/advisory-notices
# Extracting  /historic-hansard/commons/2000/jul/04/clause-89
# Extracting  /historic-hansard/commons/2000/jul/04/payments-in-cases-of-maladministration
# Extracting  /historic-hansard/commons/2000/jul/04/clause-90
# Extracting  /historic-hansard/commons/2000/jul/04/grants-for-welfare-services
# Sleeping for  3  seconds
# Extracting  /historic-hansard/commons/2000/jul/04/indemnification-of-members-and-officers
# Extracting  /historic-hansard/commons/2000/jul/04/clause-94
# Extracting  /historic-hansard/commons/2000/jul/04/allowances-and-pensions
# Extracting  /historic-hansard/commons/2000/jul/04/sea-defences-norfolk
# Extracting  /historic-hansard/commons/2000/jul/05/preamble
# Extracting  /historic-hansard/commons/2000/jul/05/prayers
# Extracting  /historic-hansard/commons/2000/jul/05/private-business
# Extracting  /historic-hansard/commons/2000/jul/05/city-of-london-ward-elections-bill-by
# Extracting  /historic-hansard/commons/2000/jul/05/oral-answers-to-questions
# Extracting  /historic-hansard/commons/2000/jul/05/international-development
# Sleeping for  1  seconds
# Extracting  /historic-hansard/commons/2000/jul/05/aid-budget-reform
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-d8cc5b8e492e> in <module>
#       2 import csv
#       3
# ----> 4 to_csv = construct_data_list(links_small)
#       5
#       6 keys = to_csv[0].keys()
#
# <ipython-input-58-650eb2194bf1> in construct_data_list(links)
#      35     # creating a dictionary entry called hansard_info
#      36       hansard_info = {}
# ---> 37       data = get_data(link)
#      38       soup = get_soup(data)
#      39
#
# <ipython-input-58-650eb2194bf1> in get_data(link)
#       2 import random
#       3 def get_data(link):
# ----> 4  return requests.get(link)
#       5
#       6 def get_soup(data):
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     490         """
#     491         if self.chunked and self.supports_chunked_reads():
# --> 492             for line in self.read_chunked(amt, decode_content=decode_content):
#     493                 yield line
#     494         else:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     666
#     667             while True:
# --> 668                 self._update_chunk_length()
#     669                 if self.chunk_left == 0:
#     670                     break
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     598         if self.chunk_left is not None:
#     599             return
# --> 600         line = self._fp.fp.readline()
#     601         line = line.split(b';', 1)[0]
#     602         try:
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('hansard.csv')
pd.set_option('display.max_colwidth', None)
df.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-a8e95babf290> in <module>
#       1 df = pd.read_csv('hansard.csv')
#       2 pd.set_option('display.max_colwidth', None)
# ----> 3 df.len()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'len'
